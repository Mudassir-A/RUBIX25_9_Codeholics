# %%
import pandas as pd

# %%
df = pd.read_json('../data/ecommerce.product_updated.json')
df.head()
# Out:
#                                     _id                       name  \
# 0  {'$oid': '673b0f5da59432e2367a5ebe'}    Radiant Glow Face Cream
# 1  {'$oid': '673b0f5da59432e2367a5ebf'}          Hydra Boost Cream
# 2  {'$oid': '673b0f5da59432e2367a5ec0'}  EcoFresh Daily Face Cream
# 3  {'$oid': '673b0f5da59432e2367a5ec1'}           EcoShine Shampoo
# 4  {'$oid': '673b0f5da59432e2367a5ec2'}        Pure Herbal Shampoo
#
#                                          description  price         category  \
# 0  Hydrating face cream infused with natural ingr...  45.99  Beauty Products
# 1  Lightweight, non-greasy face moisturizer provi...   5.50  Beauty Products
# 2  Eco-friendly face cream for everyday hydration...  52.00  Beauty Products
# 3  A nourishing shampoo enriched with natural oil...  22.99  Beauty Products
# 4  Formulated with organic herbs and plant extrac...  18.50  Beauty Products
#
#                                                image  inStock  \
# ...

# %%
df.isnull().sum()
# Out:
# _id                 0
# name                0
# description         0
# price               0
# category            0
# image               0
# inStock             0
# carbonFootprint     0
# materialSourcing    0
# recyclability       0
# waterUsage          0
# energyEfficiency    0
# biodegradability    0
# durability          0
# ecoScore            0
# productType         0
# dtype: int64

# %%
df.shape
# Out:
# (48, 16)

# %%
df.category.unique()
# Out:
# array(['Beauty Products', 'Footwear', 'Bags', 'Clothing'], dtype=object)

# %%
df.drop(columns=['_id'])
# Out:
#                            name  \
# 0       Radiant Glow Face Cream
# 1             Hydra Boost Cream
# 2     EcoFresh Daily Face Cream
# 3              EcoShine Shampoo
# 4           Pure Herbal Shampoo
# 5                Repair Shampoo
# 6        EcoLuxe Matte Lipstick
# 7          Herbal Rose Lipstick
# 8          Velvet Glow Lipstick
# 9              EcoScent Perfume
# 10     Sustainable Rose Perfume
# 11           Luxury Oud Perfume
# 12            Man Running Shoes
# 13             Man Hiking Boots
# 14         Man Leather Sneakers
# 15            Women Black Heels
# 16          Women Stylish Heels
# 17      Women High Heel Sandals
# 18      Kids Eco-Friendly Shoes
# 19           Kids Cheslea Boots
# 20           Kids Leather Boots
# 21      Unisex Purecat Slippers
# 22   Unisex Ultra-Soft Slippers
# 23        Unisex Cloud Slippers
# 24              Travel Backpack
# 25          Backpack for Hiking
# 26                 Eco Backpack
# 27               Eco Travel Bag
# ...
